# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Importing DataSet

# %%
data = pd.read_csv(r"C:\Users\AI\Downloads\covid19_Confirmed_dataset.csv")
data.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  4/21/20  4/22/20  4/23/20  4/24/20  \
# 0        0        0        0  ...     1092     1176     1279     1351
# 1        0        0        0  ...      609      634      663      678
# 2        0        0        0  ...     2811     2910     3007     3127
# 3        0        0        0  ...      717      723      723      731
# 4        0        0        0  ...       24       25       25       25
#
#    4/25/20  4/26/20  4/27/20  4/28/20  4/29/20  4/30/20
# ...

# %% [markdown]
# ### Checking Shape of Data

# %%
data.shape
# Out:
# (266, 104)

# %% [markdown]
# ### Deleting the useless columns

# %%
data.drop(['Long','Lat'],axis=1,inplace=True)

# %%
data.head(15)
# Out:
#                   Province/State       Country/Region  1/22/20  1/23/20  \
# 0                            NaN          Afghanistan        0        0
# 1                            NaN              Albania        0        0
# 2                            NaN              Algeria        0        0
# 3                            NaN              Andorra        0        0
# 4                            NaN               Angola        0        0
# 5                            NaN  Antigua and Barbuda        0        0
# 6                            NaN            Argentina        0        0
# 7                            NaN              Armenia        0        0
# 8   Australian Capital Territory            Australia        0        0
# 9                New South Wales            Australia        0        0
# 10            Northern Territory            Australia        0        0
# 11                    Queensland            Australia        0        0
# ...

# %% [markdown]
# ### Aggregating the rows by country

# %%
df = data.groupby('Country/Region').sum()

# %%
df
# Out:
#                     1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# Country/Region
# Afghanistan               0        0        0        0        0        0
# Albania                   0        0        0        0        0        0
# Algeria                   0        0        0        0        0        0
# Andorra                   0        0        0        0        0        0
# Angola                    0        0        0        0        0        0
# ...                     ...      ...      ...      ...      ...      ...
# West Bank and Gaza        0        0        0        0        0        0
# Western Sahara            0        0        0        0        0        0
# Yemen                     0        0        0        0        0        0
# Zambia                    0        0        0        0        0        0
# Zimbabwe                  0        0        0        0        0        0
#
# ...

# %% [markdown]
# ### Visualizing data related to a country
# Visulalization always helps in better understanding of data

# %%
df.loc['China'].plot()
df.loc['Italy'].plot()
df.loc['Spain'].plot()
df.loc['India'].plot()
plt.legend()

# %% [markdown]
# #### Finding first derivative and plotting the curve

# %%
df.loc['China'].diff()
# Out:
# 1/22/20      NaN
# 1/23/20     95.0
# 1/24/20    277.0
# 1/25/20    486.0
# 1/26/20    669.0
#            ...
# 4/26/20      3.0
# 4/27/20      6.0
# 4/28/20     22.0
# 4/29/20      4.0
# 4/30/20     12.0
# Name: China, Length: 100, dtype: float64

# %%
df.loc['China'].diff().plot()
# Out:
# <AxesSubplot:>

# %%
df.loc['India'].diff().plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Finding maximum infection rate of each country

# %%
df.loc['China'].diff().max()
# Out:
# 15136.0

# %%
country = list(df.index)
country
max_cases = []

# %%
for c in country:
    max_cases.append(df.loc[c].diff().max())
df['Max_infection_cases']=max_cases

# %%
df.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# Afghanistan           0        0        0        0        0        0        0
# Albania               0        0        0        0        0        0        0
# Algeria               0        0        0        0        0        0        0
# Andorra               0        0        0        0        0        0        0
# Angola                0        0        0        0        0        0        0
#
#                 1/29/20  1/30/20  1/31/20  ...  4/22/20  4/23/20  4/24/20  \
# Country/Region                             ...
# Afghanistan           0        0        0  ...     1176     1279     1351
# Albania               0        0        0  ...      634      663      678
# Algeria               0        0        0  ...     2910     3007     3127
# Andorra               0        0        0  ...      723      723      731
# ...

# %%
df1 = pd.DataFrame(df['Max_infection_cases'])

# %% [markdown]
# #### Created a new data frame using only needed columns

# %%
df1.head()
# Out:
#                 Max_infection_cases
# Country/Region
# Afghanistan                   232.0
# Albania                        34.0
# Algeria                       199.0
# Andorra                        43.0
# Angola                          5.0

# %% [markdown]
# ## Importing another datset - WorldWide Happiness Report

# %%
df2 = pd.read_csv(r"C:\Users\AI\Downloads\worldwide_happiness_report.csv")
df2.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %% [markdown]
# ### Dropping useless columns

# %%
columns = ['Overall rank','Score','Generosity','Perceptions of corruption']

# %%
df2.drop(columns,axis=1,inplace=True)

# %%
df2.head()
# Out:
#   Country or region  GDP per capita  Social support  Healthy life expectancy  \
# 0           Finland           1.340           1.587                    0.986
# 1           Denmark           1.383           1.573                    0.996
# 2            Norway           1.488           1.582                    1.028
# 3           Iceland           1.380           1.624                    1.026
# 4       Netherlands           1.396           1.522                    0.999
#
#    Freedom to make life choices
# 0                         0.596
# 1                         0.592
# 2                         0.603
# 3                         0.591
# 4                         0.557

# %% [markdown]
# ####  Changing name of index

# %%
df2.set_index("Country or region",inplace=True)

# %%
df2.head()
# Out:
#                    GDP per capita  Social support  Healthy life expectancy  \
# Country or region
# Finland                     1.340           1.587                    0.986
# Denmark                     1.383           1.573                    0.996
# Norway                      1.488           1.582                    1.028
# Iceland                     1.380           1.624                    1.026
# Netherlands                 1.396           1.522                    0.999
#
#                    Freedom to make life choices
# Country or region
# Finland                                   0.596
# Denmark                                   0.592
# Norway                                    0.603
# Iceland                                   0.591
# Netherlands                               0.557

# %% [markdown]
# #### Merging Covid19 data and Worldwide Happiness report data

# %%
merged_data = df1.join(df2,how="inner")

# %%
merged_data.head()
# Out:
#              Max_infection_cases  GDP per capita  Social support  \
# Afghanistan                232.0           0.350           0.517
# Albania                     34.0           0.947           0.848
# Algeria                    199.0           1.002           1.160
# Argentina                  291.0           1.092           1.432
# Armenia                    134.0           0.850           1.055
#
#              Healthy life expectancy  Freedom to make life choices
# Afghanistan                    0.361                         0.000
# Albania                        0.874                         0.383
# Algeria                        0.785                         0.086
# Argentina                      0.881                         0.471
# Armenia                        0.815                         0.283

# %% [markdown]
# ### correlation matrix

# %%
merged_data.corr()
# Out:
#                               Max_infection_cases  GDP per capita  \
# Max_infection_cases                      1.000000        0.250118
# GDP per capita                           0.250118        1.000000
# Social support                           0.191958        0.759468
# Healthy life expectancy                  0.289263        0.863062
# Freedom to make life choices             0.078196        0.394603
#
#                               Social support  Healthy life expectancy  \
# Max_infection_cases                 0.191958                 0.289263
# GDP per capita                      0.759468                 0.863062
# Social support                      1.000000                 0.765286
# Healthy life expectancy             0.765286                 1.000000
# Freedom to make life choices        0.456246                 0.427892
#
#                               Freedom to make life choices
# Max_infection_cases                               0.078196
# ...

# %% [markdown]
# ### Visualization of results

# %%
merged_data.head()
# Out:
#              Max_infection_cases  GDP per capita  Social support  \
# Afghanistan                232.0           0.350           0.517
# Albania                     34.0           0.947           0.848
# Algeria                    199.0           1.002           1.160
# Argentina                  291.0           1.092           1.432
# Armenia                    134.0           0.850           1.055
#
#              Healthy life expectancy  Freedom to make life choices
# Afghanistan                    0.361                         0.000
# Albania                        0.874                         0.383
# Algeria                        0.785                         0.086
# Argentina                      0.881                         0.471
# Armenia                        0.815                         0.283

# %% [markdown]
# ##### Plotting GDP vs Max Infection Cases

# %%
x = merged_data["GDP per capita"]
y = merged_data["Max_infection_cases"]
sns.scatterplot(x,y)
# Out:
# C:\Users\AI\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='GDP per capita', ylabel='Max_infection_cases'>

# %% [raw]
# In the above graph, as GDP increases maximun infected cases also increases but we can't get much details from this graph because of the heavy difference in the range of the values of x and y axis.
# So to solve this problem we can use log scaling in the y axis

# %%
x = merged_data["GDP per capita"]
y = merged_data["Max_infection_cases"]
sns.scatterplot(x,np.log(y))
# Out:
# C:\Users\AI\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='GDP per capita', ylabel='Max_infection_cases'>

# %%
x = merged_data["GDP per capita"]
y = merged_data["Max_infection_cases"]
sns.regplot(x,np.log(y))
# Out:
# C:\Users\AI\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='GDP per capita', ylabel='Max_infection_cases'>

# %% [raw]
# **The above graph shows that people who are living in more developed country are more prone to getting infected by Corona Virus**

# %% [markdown]
# ##### Plotting GDP vs Social Support

# %%
x = merged_data["Social support"]
y = merged_data["Max_infection_cases"]
sns.scatterplot(x,y)
# Out:
# C:\Users\AI\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Social support', ylabel='Max_infection_cases'>

# %%
x = merged_data["Social support"]
y = merged_data["Max_infection_cases"]
sns.scatterplot(x,np.log(y))
# Out:
# C:\Users\AI\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Social support', ylabel='Max_infection_cases'>

# %%
x = merged_data["Social support"]
y = merged_data["Max_infection_cases"]
sns.regplot(x,np.log(y))
# Out:
# C:\Users\AI\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Social support', ylabel='Max_infection_cases'>

# %% [markdown]
# ##### Plotting GDP vs Healthy life expectancy

# %%
x = merged_data["Healthy life expectancy"]
y = merged_data["Max_infection_cases"]
sns.regplot(x,np.log(y))
# Out:
# C:\Users\AI\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Healthy life expectancy', ylabel='Max_infection_cases'>

# %% [markdown]
# ##### Plotting GDP vs Freedom to make life choices

# %%
x = merged_data["Freedom to make life choices"]
y = merged_data["Max_infection_cases"]
sns.regplot(x,np.log(y))
# Out:
# C:\Users\AI\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Freedom to make life choices', ylabel='Max_infection_cases'>
